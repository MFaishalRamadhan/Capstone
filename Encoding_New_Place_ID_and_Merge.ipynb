# %% [markdown]
# <a href="https://colab.research.google.com/github/MFaishalRamadhan/Capstone/blob/main/Encoding_New_Place_ID_and_Merge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# Load place dataset
from google.colab import drive
drive.mount("/content/gdrive")
place_dataset = pd.read_excel(r'/content/gdrive/My Drive/Colab Notebooks/Dataset/Dataset Tempat.xlsx')
place_dataset.head()
# Out:
# Mounted at /content/gdrive
#    Place_ID                                             Name  \
# 0        11                                 Mr.K Cafe Gombel
# 1        12                           Super Penyet Setiabudi
# 2        13       Sim Six (Sim-6) garden Resto Ngesrep timur
# 3        14                                 Sowak (Sop Iwak)
# 4        15  Warung Lesehan Fifty Fifty Sumurboto Banyumanik
#
#                                                Image  \
# 0  https://lh5.googleusercontent.com/p/AF1QipOh43...
# 1  https://lh5.googleusercontent.com/p/AF1QipMufn...
# 2  https://lh5.googleusercontent.com/p/AF1QipPfQx...
# 3  https://lh5.googleusercontent.com/p/AF1QipPKYy...
# 4  https://lh5.googleusercontent.com/p/AF1QipNxvJ...
#
#                                                  URL  Rating  Num_Rating  \
# 0  https://www.google.com/maps/place/Mr.K+Cafe+Go...     4.5        6235
# 1  https://www.google.com/maps/place/Super+Penyet...     4.4        5702
# ...

# %%
# Load review user dataset
from google.colab import drive
drive.mount("/content/gdrive")
rating_dataset = pd.read_excel(r'/content/gdrive/My Drive/Colab Notebooks/Dataset/Dataset Rating Users.xlsx')
rating_dataset.head()
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#    User_ID  Place_ID  Rating
# 0        1        12       1
# 1        1        13       1
# 2        1        13       3
# 3        1        29       4
# 4        1        31       4

# %%
place_id_mapping = {}
new_place_id_counter = 1

# %%
for index, row in place_dataset.iterrows():
    existing_place_id = row['Place_ID']
    place_id_mapping[existing_place_id] = new_place_id_counter
    new_place_id_counter += 1

# %%
# Replace place IDs in place_data using new place IDs
place_dataset['Place_ID'] = place_dataset['Place_ID'].map(place_id_mapping)

# %%
place_dataset
# Out:
#      Place_ID                                               Name  \
# 0           1                                   Mr.K Cafe Gombel
# 1           2                             Super Penyet Setiabudi
# 2           3         Sim Six (Sim-6) garden Resto Ngesrep timur
# 3           4                                   Sowak (Sop Iwak)
# 4           5    Warung Lesehan Fifty Fifty Sumurboto Banyumanik
# ..        ...                                                ...
# 560       561                                       Eastman Café
# 561       562  KOJA KOPI BAJA + BAHAN MATERIAL BANGUNAN SEGAL...
# 562       563                                    Angkringan Tugu
# 563       564                                          KL Coffee
# 564       565                                  Point Coffee KITW
#
#                                                  Image  \
# 0    https://lh5.googleusercontent.com/p/AF1QipOh43...
# 1    https://lh5.googleusercontent.com/p/AF1QipMufn...
# ...

# %%
# Replace place IDs in review_data using new place IDs
rating_dataset['Place_ID'] = rating_dataset['Place_ID'].map(place_id_mapping)

# %%
rating_dataset
# Out:
#         User_ID  Place_ID  Rating
# 0             1         2       1
# 1             1         3       1
# 2             1         3       3
# 3             1        19       4
# 4             1        21       4
# ...         ...       ...     ...
# 822816    18002        90       2
# 822817    18002        90       2
# 822818    18002        93       1
# 822819    18002        95       3
# 822820    18002        96       3
#
# [822821 rows x 3 columns]

# %%
users_dataset = rating_dataset.merge(place_dataset, on='Place_ID')

# %%
users_dataset
# Out:
#         User_ID  Place_ID  Rating_x                                    Name  \
# 0             1         2         1                  Super Penyet Setiabudi
# 1             4         2         2                  Super Penyet Setiabudi
# 2             7         2         2                  Super Penyet Setiabudi
# 3            22         2         2                  Super Penyet Setiabudi
# 4            22         2         3                  Super Penyet Setiabudi
# ...         ...       ...       ...                                     ...
# 822816    16192       400         4               Civita Souvenir Tembalang
# 822817    16815       400         4               Civita Souvenir Tembalang
# 822818    17271       392         1                         LuXury Souvenir
# 822819    17292       391         3  Packachy Packing and Souvenir Semarang
# 822820    17301       371         2               Souvenir & Mahar Mbak Iin
#
# ...

# %%
users_dataset.to_excel('Users_Dataset.xlsx', index=False)
